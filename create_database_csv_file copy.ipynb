# %%
import glob
import pandas as pd

#IMPORTING FUNCTIONS FROM ./defs
from defs import defs_copy as defs_

# %% [markdown]
# # Gerando e importando arquivos do database em .csv

# %%
#PATHS USED
path_quick_test = [
    "./database_raw/DatasetA/zzzAD1.txt",
    "./database_raw/DatasetA/zzzAD30.txt",
    "./database_raw/DatasetA/zzzAD12.txt",
    "./database_raw/DatasetA/zzzAU.txt",
]

path = glob.glob("./database_raw/DatasetA/zzzA*.txt", recursive=True)

pathB = glob.glob("./database_raw/DatasetB/zzzB*.txt", recursive=True)

# Qty of row to be aggrouped 
samples = 1024

# %%
# Initiate DF's

#!!! You need to create a folder under df_csv/ with name '<samples>_samples' !!!

# Create full database with all data available on DATASETA
df_final = defs_.prepareDatabase(path, samples, typeof='both');
# Instead of creating database every time, it was exported as a csv file named 'dataframe_final' on root of project, imported using following code
df_final.to_csv('df_csv/' + str(samples) + '_samples/dataframe_full')
#######
## Example of code to import database as pd
# df_final = pd.read_csv('df_csv/' + str(samples) + '_samples/dataframe_final', index_col=0, dtype='unicode');
#######

### time: 6m 15s

df_final
# Out:
#       s_std_S1  psd_max_S1   mean_S1  median_S1   skew_S1  amp_max_min_S1  \
# 0     0.000365    0.000001 -0.001358  -0.002283  0.015408        0.993947
# 1     0.000422    0.000007 -0.000405   0.001573 -0.031585        0.930550
# 2     0.000416    0.000015  0.002315   0.002927 -0.003201        1.337910
# 3     0.000507    0.000032  0.002870   0.007315  0.045592        1.307263
# 4     0.000490    0.000048  0.001293   0.006328 -0.133435        1.341857
# ...        ...         ...       ...        ...       ...             ...
# 7931  0.000465    0.121070  0.004768   0.002093 -0.033073        1.017505
# 7932  0.000431    0.121928  0.005682   0.004894 -0.013128        1.087860
# 7933  0.000441    0.122930  0.004502   0.000791  0.123470        1.348512
# 7934  0.000451    0.124097  0.005475   0.002469  0.070692        1.155474
# 7935  0.000429    0.124989  0.006586   0.008707 -0.012548        1.222844
#
#       kurtosis_S1  s_std_S2  psd_max_S2   mean_S2  ...  amp_max_min_S29  \
# 0        0.103656  0.000364    0.000001  0.000373  ...         0.933404
# 1       -0.101231  0.000395    0.000008  0.000113  ...         0.817396
# 2        0.478070  0.000441    0.000017  0.001648  ...         0.992125
# 3       -0.361960  0.000532    0.000034  0.002983  ...         1.273238
# 4        0.338595  0.000516    0.000049  0.003655  ...         1.173373
# ...           ...       ...         ...       ...  ...              ...
# 7931    -0.172763  0.000439    0.121019  0.001932  ...         1.092261
# 7932    -0.184804  0.000418    0.121934  0.002095  ...         1.038342
# 7933     0.069060  0.000447    0.122927  0.000161  ...         1.028297
# 7934     0.104520  0.000438    0.123959  0.000946  ...         0.930920
# 7935     0.140596  0.000412    0.125073  0.001988  ...         0.954796
#
#       kurtosis_S29  s_std_S30  psd_max_S30  mean_S30  median_S30  skew_S30  \
# 0        -0.041879   0.000369     0.000001 -0.000963   -0.001607 -0.028262
# 1         0.221911   0.000372     0.000006 -0.000741    0.003108 -0.139601
# 2        -0.045582   0.000384     0.000015 -0.001060   -0.003839  0.152689
# 3        -0.060022   0.000441     0.000030 -0.000610   -0.000826 -0.034338
# 4         0.212665   0.000401     0.000044 -0.000836    0.005241 -0.103854
# ...            ...        ...          ...       ...         ...       ...
# 7931     -0.193278   0.000410     0.121019  0.002227    0.004261 -0.060723
# 7932      0.041517   0.000393     0.121885  0.001673    0.009320 -0.062856
# 7933     -0.182436   0.000419     0.122887  0.001823    0.005102  0.127894
# 7934     -0.068653   0.000394     0.123843  0.001275   -0.000052  0.024124
# 7935     -0.065528   0.000401     0.124939  0.001505    0.000654  0.030903
#
#       amp_max_min_S30  kurtosis_S30  Scenario
# 0            0.976326      0.374172         1
# 1            0.876666     -0.195976         1
# 2            0.896421      0.019831         1
# 3            1.078106     -0.092535         1
# 4            1.037670      0.058457         1
# ...               ...           ...       ...
# 7931         0.939671     -0.072852         0
# 7932         1.032867      0.238116         0
# 7933         1.002445     -0.116651         0
# 7934         0.837480     -0.053772         0
# 7935         0.931408      0.004003         0
#
# [7936 rows x 211 columns]

# %%
# Initiate DF's

#!!! You need to create a folder under df_csv/ with name '<samples>_samples' !!!

# Create full database with all data available on DATASETA
df_final = defs_.prepareDatabase(pathB, samples, typeof='both');
# Instead of creating database every time, it was exported as a csv file named 'dataframe_final' on root of project, imported using following code
df_final.to_csv('df_csv/' + str(samples) + '_samples/dataframeB_full')
#######
## Example of code to import database as pd
# df_final = pd.read_csv('df_csv/' + str(samples) + '_samples/dataframe_final', index_col=0, dtype='unicode');
#######

### time: 6m 15s

df_final
# Out:
#       s_std_S1  psd_max_S1   mean_S1  median_S1   skew_S1  amp_max_min_S1  \
# 0     0.000375    0.000001 -0.001299   0.005691 -0.110667        0.986940
# 1     0.000413    0.000006 -0.001121  -0.005453  0.094418        1.130466
# 2     0.000492    0.000019 -0.000137  -0.009470  0.143951        1.319181
# 3     0.000447    0.000029  0.001781   0.000346  0.046062        1.353815
# 4     0.000417    0.000049  0.001525   0.004632 -0.023202        1.182640
# ...        ...         ...       ...        ...       ...             ...
# 7931  0.000445    0.121225 -0.005335  -0.002186 -0.027338        1.220160
# 7932  0.000465    0.121961 -0.004273  -0.004680  0.029061        1.273108
# 7933  0.000453    0.123085 -0.003399  -0.007203  0.078415        1.102442
# 7934  0.000413    0.123936 -0.000344   0.001014  0.061073        0.875458
# 7935  0.000455    0.124973 -0.000309  -0.005484  0.060146        1.021658
#
#       kurtosis_S1  s_std_S2  psd_max_S2   mean_S2  ...  amp_max_min_S29  \
# 0       -0.096554  0.000367    0.000002 -0.000846  ...         0.860303
# 1       -0.052245  0.000454    0.000007 -0.000444  ...         0.959107
# 2       -0.025370  0.000465    0.000017 -0.000124  ...         0.959374
# 3        0.057746  0.000485    0.000029  0.000371  ...         0.890721
# 4        0.076125  0.000404    0.000047  0.002728  ...         1.121152
# ...           ...       ...         ...       ...  ...              ...
# 7931     0.129227  0.000423    0.121138 -0.002862  ...         0.978243
# 7932     0.017920  0.000438    0.122022 -0.001568  ...         0.971918
# 7933    -0.110298  0.000450    0.122943 -0.002246  ...         0.969746
# 7934    -0.227583  0.000410    0.123859 -0.000641  ...         0.794648
# 7935    -0.214437  0.000431    0.124868 -0.000622  ...         0.959681
#
#       kurtosis_S29  s_std_S30  psd_max_S30  mean_S30  median_S30  skew_S30  \
# 0         0.101280   0.000353     0.000002  0.001679    0.011077 -0.047370
# 1         0.045936   0.000388     0.000007  0.001921    0.006029 -0.048384
# 2        -0.188526   0.000404     0.000016  0.001608   -0.007312  0.090463
# 3        -0.029459   0.000445     0.000029  0.001518    0.011066 -0.135156
# 4         0.216245   0.000385     0.000048  0.001940    0.001546  0.190760
# ...            ...        ...          ...       ...         ...       ...
# 7931     -0.095953   0.000377     0.121033 -0.000733   -0.002443  0.075173
# 7932     -0.303714   0.000401     0.121992 -0.000464   -0.003423  0.036905
# 7933     -0.139506   0.000402     0.122815 -0.000894    0.001106  0.019761
# 7934     -0.339269   0.000357     0.123756 -0.000529    0.000163  0.080961
# 7935     -0.030925   0.000396     0.124860 -0.000533    0.001821  0.050370
#
#       amp_max_min_S30  kurtosis_S30  Scenario
# 0            0.920191     -0.055911         1
# 1            0.931387      0.007701         1
# 2            0.862714     -0.206926         1
# 3            1.046320     -0.102855         1
# 4            1.133867      0.417386         1
# ...               ...           ...       ...
# 7931         0.871732     -0.051098         0
# 7932         0.987719     -0.145565         0
# 7933         0.918889     -0.018330         0
# 7934         0.684635     -0.188585         0
# 7935         0.787245     -0.316640         0
#
# [7936 rows x 211 columns]
