# %%
import matplotlib.pyplot as plt

# %%
# Check values from database's target 
plt.figure()
plt.title("Representatividade da variável objetivo");
plt.xlabel('Valor');
plt.ylabel('Média   Desvio Padrão   Min Max     Mediana     Skewness    Amplitude   Kurtosis');
